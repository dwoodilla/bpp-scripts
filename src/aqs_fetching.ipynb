# %%
# %pip install pyaqsapi
# %pip install certifi
# %pip install requests
# %pip install pandas
import pyaqsapi as aqs
from datetime import date

aqs.aqs_credentials(username='david_mike_woodilla@brown.edu', key='ochrecrane43')
bdate = date(2024,12,1); edate=date(2025,6,1)
display(aqs.by)
# Out:
#                                                               0    \
# state_code                                                     44
# county_code                                                   007
# site_number                                                  0022
# parameter_code                                              43220
# poc                                                             2
# parameter_name                                          n-Pentane
# open_date                                              2001-05-18
# close_date                                                   None
# concurred_exclusions                                         None
# dominant_source                                              None
# measurement_scale                                            None
# measurement_scale_def                                        None
# monitoring_objective                                      UNKNOWN
# ...
